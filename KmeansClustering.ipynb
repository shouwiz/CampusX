# %% [markdown]
# <a href="https://colab.research.google.com/github/shouwiz/CampusX/blob/KMeans_Clustering/KmeansClustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("student_clustering.csv")
df.shape
# Out:
# (200, 2)

# %%
df.head()
# Out:
#    cgpa   iq
# 0  5.13   88
# 1  5.90  113
# 2  8.36   93
# 3  8.27   97
# 4  5.45  110

# %%
plt.scatter(df['cgpa'],df['iq'])

# %%
from sklearn.cluster import KMeans

# %%
#elbow method
wcss = []
for i in range(1,11):
  km = KMeans(n_clusters=i)
  km.fit_predict(df)
  wcss.append(km.inertia_)

# %%
wcss
# Out:
# [29957.898287999997,
#  4184.141269999999,
#  2362.7133490000015,
#  681.9696600000001,
#  587.7764274703555,
#  457.4399115943195,
#  314.8894088678235,
#  266.200952547939,
#  271.81977588224225,
#  185.3014074381188]

# %%
plt.plot(range(1,11),wcss)
#the slope starts to flatten after 4 so only 4 clusters are required

# %%
X = df.iloc[:,:].values
km = KMeans(n_clusters=4)
y_means = km.fit_predict(X)

# %%
y_means
# Out:
# array([2, 3, 0, 0, 3, 3, 0, 1, 3, 0, 2, 3, 0, 2, 3, 0, 3, 0, 3, 3, 0, 2,
#        0, 2, 2, 0, 2, 1, 0, 3, 1, 3, 1, 3, 0, 0, 1, 3, 2, 3, 2, 0, 0, 2,
#        1, 1, 0, 3, 1, 3, 2, 2, 1, 0, 1, 3, 3, 1, 3, 1, 3, 0, 0, 1, 2, 1,
#        0, 2, 3, 0, 3, 1, 0, 2, 3, 1, 3, 1, 2, 0, 0, 1, 3, 2, 1, 2, 1, 3,
#        1, 3, 1, 1, 0, 2, 0, 0, 1, 0, 2, 1, 3, 2, 2, 1, 2, 2, 0, 2, 1, 1,
#        0, 1, 3, 3, 0, 1, 0, 3, 1, 2, 2, 3, 0, 1, 0, 2, 0, 3, 2, 0, 0, 3,
#        2, 2, 3, 1, 3, 2, 0, 0, 0, 2, 3, 2, 2, 1, 2, 1, 3, 2, 1, 2, 1, 1,
#        2, 0, 3, 1, 3, 0, 2, 1, 3, 0, 1, 2, 3, 2, 2, 1, 1, 3, 1, 2, 2, 0,
#        1, 3, 2, 1, 1, 3, 3, 3, 0, 2, 0, 0, 1, 3, 0, 0, 2, 2, 0, 2, 1, 3,
#        3, 1], dtype=int32)

# %%
X[y_means == 2]
# Out:
# array([[ 5.13, 88.  ],
#        [ 4.6 , 86.  ],
#        [ 5.  , 88.  ],
#        [ 4.86, 86.  ],
#        [ 4.78, 87.  ],
#        [ 4.96, 88.  ],
#        [ 4.86, 87.  ],
#        [ 5.44, 84.  ],
#        [ 5.34, 85.  ],
#        [ 5.31, 86.  ],
#        [ 5.14, 83.  ],
#        [ 4.95, 86.  ],
#        [ 5.21, 87.  ],
#        [ 4.91, 85.  ],
#        [ 5.28, 83.  ],
#        [ 5.15, 88.  ],
#        [ 4.9 , 85.  ],
#        [ 4.89, 88.  ],
#        [ 5.05, 86.  ],
#        [ 4.98, 91.  ],
#        [ 5.01, 86.  ],
#        [ 4.95, 88.  ],
#        [ 4.96, 89.  ],
#        [ 4.85, 86.  ],
#        [ 4.76, 90.  ],
#        [ 4.98, 87.  ],
#        [ 4.78, 87.  ],
#        [ 5.2 , 85.  ],
#        [ 5.05, 87.  ],
#        [ 5.01, 83.  ],
#        [ 4.77, 86.  ],
#        [ 4.68, 87.  ],
#        [ 4.81, 85.  ],
#        [ 5.03, 87.  ],
#        [ 4.98, 87.  ],
#        [ 5.32, 88.  ],
#        [ 4.86, 88.  ],
#        [ 4.89, 85.  ],
#        [ 4.88, 86.  ],
#        [ 5.01, 86.  ],
# ...

# %%
X[y_means == 3]
# Out:
# array([[  5.9 , 113.  ],
#        [  5.45, 110.  ],
#        [  5.88, 109.  ],
#        [  5.79, 110.  ],
#        [  6.1 , 110.  ],
#        [  5.71, 108.  ],
#        [  5.5 , 111.  ],
#        [  6.05, 111.  ],
#        [  5.84, 113.  ],
#        [  5.43, 106.  ],
#        [  6.01, 112.  ],
#        [  5.32, 106.  ],
#        [  5.91, 108.  ],
#        [  5.57, 113.  ],
#        [  6.4 , 108.  ],
#        [  5.67, 109.  ],
#        [  6.05, 108.  ],
#        [  5.85, 111.  ],
#        [  5.87, 109.  ],
#        [  6.02, 104.  ],
#        [  5.77, 111.  ],
#        [  6.06, 109.  ],
#        [  5.55, 109.  ],
#        [  5.81, 112.  ],
#        [  5.47, 111.  ],
#        [  5.74, 109.  ],
#        [  5.8 , 108.  ],
#        [  5.88, 110.  ],
#        [  5.91, 109.  ],
#        [  5.67, 111.  ],
#        [  5.74, 108.  ],
#        [  5.69, 109.  ],
#        [  6.05, 109.  ],
#        [  6.14, 111.  ],
#        [  5.74, 112.  ],
#        [  5.94, 109.  ],
#        [  5.86, 111.  ],
# ...

# %%
plt.scatter(X[y_means == 0,0],X[y_means == 0,1],color='blue')
plt.scatter(X[y_means == 1,0],X[y_means == 1,1],color='red')
plt.scatter(X[y_means == 2,0],X[y_means == 2,1],color='green')
plt.scatter(X[y_means == 3,0],X[y_means == 3,1],color='yellow')

# %%
f
